# %% [markdown]
# # SESSION PLAN
#
# - Complete Group Exercise Challenges
# - Present your solutions
# - Review examples solution provided by your instructor
# - Group work on your projects (remaining time)

# %% [markdown]
# ## Matplotlib Exercises
#
# - In this challenge, we are using Pandas and Matplotlib to visualize Company Sales Data.
# - Please use __company_sales_data.csv__ file. Read data with Pandas to load into your Jupyter.
# - Each exercise will be completed in group.
# - You have 20 minutes to solve each task as a group
# - After 20 min your instructor will pick one or two teams at random to present their solution
# - Solutions to be presented  EVEN IF they are not completed (we want to hear your thoughts on how to solve it more than your correct syntax)
# - Your instructor will share example solution to each exercise.

# %% [markdown]
# # Challenge 1
#
# <div class="alert alert-block alert-info">
# Use company sales data to read sales figures for face cream and facewash product.
# Show the comparisons using the bar chart.
# </div>
#
# - Your chart should show the number of units sold per month for each product.
# - Include a separate bar for each product.
#
# - EXAMPLE OUTPUT:
#
#  <img src="../data/images/challenge3.jpg" style="width: 500px">
#
#
#  ### 20 min START NOW

# %%
# EXAMPLE SOLUTION

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
# plt.subplots(figsize=(30,18))
plt.figure(figsize=(30,10))

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash sales data', align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')

plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
# plt.show()
# Out:
# Text(0.5, 1.0, 'Facewash and facecream sales data')

# %% [markdown]
# # Challenge 2
#
# <div class="alert alert-block alert-info">
# Use company sales data to calculate total for last year for each product.
# Use Pie chart to present data
# </div>
#
# - NB: please isplay number of units sold per year for each product as percentage
#
# - EXAMPLE OUTPUT:
#
#  <img src="../data/images/challenge4.jpg" style="width: 500px">
#
#
#  ### 20 min START NOW

# %%
# EXAMPLE SOLUTION

import pandas as pd
import matplotlib.pyplot as plt  

df = pd.read_csv("company_sales_data.csv")

labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData  = [df ['facecream'].sum(), df ['facewash'].sum(), df ['toothpaste'].sum(), 
         df ['bathingsoap'].sum(), df ['shampoo'].sum(), df ['moisturizer'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels, autopct='%1.1f%%')
plt.legend(loc='lower right') # optional
plt.title('Sales data')
plt.show()

# %% [markdown]
# # PROJECT WORK IN GROUPS
#
# <img src="../data/images/project-work.jpg" style="width: 500px">
